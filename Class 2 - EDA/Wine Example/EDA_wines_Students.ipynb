# %% [markdown]
# # Practice Exercise: Exploratory Data Analysis

# %% [markdown]
# ## Context:
#
# - The dataset is related to the Portuguese "Vinho Verde" wine.
# - Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# - This datasets can be viewed as classification or regression tasks.
# - The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones).
# - Outlier detection algorithms could be used to detect the few excellent or poor wines.
# - Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.

# %% [markdown]
# ## Objective:
#
# - The objective of this exercise is to analyse the characteristics of wine using statistical techniques (also known as Exploratory Data Analysis).

# %% [markdown]
# ## Data Description:
#
# Attribute Information:
#
#   - fixed acidity
#   - volatile acidity
#   - citric acid
#   - residual sugar
#   - chlorides
#   - free sulfur dioxide
#   - total sulfur dioxide
#   - density
#   - pH
#   - sulphates
#   - alcohol
#   - quality (score between 0 and 10)

# %% [markdown]
# ## 1. Import the libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## 2. Importing the dataset:

# %%
wines = pd.read_csv('wine_data.csv', sep=';')
wines.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.8               NaN         0.23             4.6     661.10
# 1            6.2              0.46         0.25             4.4     660.30
# 2            6.0               NaN         0.28             4.8     630.20
# 3            6.2               NaN         0.43             7.8     560.09
# 4            8.6               NaN         0.46             1.0     540.80
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   45                 238.5   0.9958  3.32       0.60
# 1                   45                 207.0   0.9939  3.25       0.52
# 2                   45                 201.0   0.9964  3.69       0.71
# 3                   45                 244.0   0.9956  3.10       0.51
# 4                   45                  72.0   0.9941  2.95       0.49
#
#    alcohol  quality
# 0      9.5        5
# 1      9.8        5
# 2     10.0        5
# 3      9.0        6
# 4      9.1        6

# %% [markdown]
# ## 3. Check the information about data and data-types of each respective attributes:

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      2115 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   int64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(10), int64(2)
# memory usage: 459.3 KB

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       2115.000000  4898.000000     4898.000000
# mean        6.854788          0.279369     0.334192        6.391415
# std         0.843868          0.101940     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.005000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000               4898.0           4898.000000  4898.000000
# mean      4.713856                 45.0            138.360657     1.548363
# std      47.178577                  0.0             42.498065     6.838541
# min       0.009000                 45.0              9.000000     0.987110
# 25%       0.036000                 45.0            108.000000     0.991723
# 50%       0.043000                 45.0            134.000000     0.993740
# 75%       0.050000                 45.0            167.000000     0.996100
# max     661.100000                 45.0            440.000000   103.898000
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.535149     5.877909
# std       0.151001     0.114126     1.261055     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
# ## 4. EDA Descriptive Statistics:

# %% [markdown]
# ### 4.1.  Measures of Central Tendency
#
# Measures of Central Tendency define significant, representative and adequate values for a set of data, depending on what you want to analyze. They are the
#
# 1. mean
# 2. median
# 3. quantiles and mode.

# %% [markdown]
# ### 4.2 Check the  mean ,Mode, Median and Quantile for dataset?

# %% [markdown]
# #### Mean

# %%
wines.mean()
# Out:
# fixed acidity             6.854788
# volatile acidity          0.279369
# citric acid               0.334192
# residual sugar            6.391415
# chlorides                 4.713856
# free sulfur dioxide      45.000000
# total sulfur dioxide    138.360657
# density                   1.548363
# pH                        3.188267
# sulphates                 0.489847
# alcohol                  10.535149
# quality                   5.877909
# dtype: float64

# %% [markdown]
# #### Mode

# %%
wines.mode()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.8              0.25          0.3             1.2      0.036
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   45                 111.0    0.992  3.14        0.5
#
#    alcohol  quality
# 0      9.4        6

# %% [markdown]
# #### Median and Quantile

# %%
wines.median()
# Out:
# fixed acidity             6.80000
# volatile acidity          0.26000
# citric acid               0.32000
# residual sugar            5.20000
# chlorides                 0.04300
# free sulfur dioxide      45.00000
# total sulfur dioxide    134.00000
# density                   0.99374
# pH                        3.18000
# sulphates                 0.47000
# alcohol                  10.40000
# quality                   6.00000
# dtype: float64

# %% [markdown]
# ### check (Quantile 25%,50%,75%) for dataset

# %% [markdown]
# #### Quantile 25%

# %%
wines.quantile(q=0.25)                       # Returns the value below which 25% of the data lies.
# Out:
# fixed acidity             6.300000
# volatile acidity          0.210000
# citric acid               0.270000
# residual sugar            1.700000
# chlorides                 0.036000
# free sulfur dioxide      45.000000
# total sulfur dioxide    108.000000
# density                   0.991723
# pH                        3.090000
# sulphates                 0.410000
# alcohol                   9.500000
# quality                   5.000000
# Name: 0.25, dtype: float64

# %% [markdown]
# #### Quantile 50%

# %%
wines.quantile(q=0.50)                       # Prints the value below which 50% of the data lies.
# Out:
# fixed acidity             6.80000
# volatile acidity          0.26000
# citric acid               0.32000
# residual sugar            5.20000
# chlorides                 0.04300
# free sulfur dioxide      45.00000
# total sulfur dioxide    134.00000
# density                   0.99374
# pH                        3.18000
# sulphates                 0.47000
# alcohol                  10.40000
# quality                   6.00000
# Name: 0.5, dtype: float64

# %% [markdown]
# #### Quantile 75%

# %%
wines.quantile(q=0.75)                       # Prints the value below which 75% of the data lies.
# Out:
# fixed acidity             7.3000
# volatile acidity          0.3200
# citric acid               0.3900
# residual sugar            9.9000
# chlorides                 0.0500
# free sulfur dioxide      45.0000
# total sulfur dioxide    167.0000
# density                   0.9961
# pH                        3.2800
# sulphates                 0.5500
# alcohol                  11.4000
# quality                   6.0000
# Name: 0.75, dtype: float64

# %% [markdown]
# ## 5. Check the data description:

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       2115.000000  4898.000000     4898.000000
# mean        6.854788          0.279369     0.334192        6.391415
# std         0.843868          0.101940     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.005000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000               4898.0           4898.000000  4898.000000
# mean      4.713856                 45.0            138.360657     1.548363
# std      47.178577                  0.0             42.498065     6.838541
# min       0.009000                 45.0              9.000000     0.987110
# 25%       0.036000                 45.0            108.000000     0.991723
# 50%       0.043000                 45.0            134.000000     0.993740
# 75%       0.050000                 45.0            167.000000     0.996100
# max     661.100000                 45.0            440.000000   103.898000
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.535149     5.877909
# std       0.151001     0.114126     1.261055     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
# ## 6. Measures of Dispersion

# %% [markdown]
# Measures of Dispersion are measures that indicate how spread the data is, or how they vary. The measures of dispersion are range, variance, standard deviation and the absolute deviation, or mean absolute deviation.

# %% [markdown]
# ### 6.1 check the Range,Variance,Standard Deviation,Absolute Deviation or Mean Absolute Deviation?

# %%
wines.quantile(q=0.75) - wines.quantile(q=0.25)
# Out:
# fixed acidity            1.000000
# volatile acidity         0.110000
# citric acid              0.120000
# residual sugar           8.200000
# chlorides                0.014000
# free sulfur dioxide      0.000000
# total sulfur dioxide    59.000000
# density                  0.004377
# pH                       0.190000
# sulphates                0.140000
# alcohol                  1.900000
# quality                  1.000000
# dtype: float64

# %% [markdown]
# #### The above output represents the IQR values for all the attributes.

# %% [markdown]
# #### Range

# %%
print(wines.max() - wines.min())
# Out:
# fixed acidity            10.40000
# volatile acidity          0.92500
# citric acid               1.66000
# residual sugar           65.20000
# chlorides               661.09100
# free sulfur dioxide       0.00000
# total sulfur dioxide    431.00000
# density                 102.91089
# pH                        1.10000
# sulphates                 0.86000
# alcohol                   6.20000
# quality                   6.00000
# dtype: float64

# %% [markdown]
# #### The above output represents the difference between the highest and the lowest values for each individual attributes.

# %% [markdown]
# #### Variance

# %%
print(wines.var())                     # Prints the variance of the data.
# Out:
# fixed acidity              0.712114
# volatile acidity           0.010392
# citric acid                0.014646
# residual sugar            25.725770
# chlorides               2225.818110
# free sulfur dioxide        0.000000
# total sulfur dioxide    1806.085491
# density                   46.765637
# pH                         0.022801
# sulphates                  0.013025
# alcohol                    1.590259
# quality                    0.784356
# dtype: float64

# %% [markdown]
# #### The above output represents the data dispersion on the square scale.

# %% [markdown]
# #### Standard Deviation

# %%
print(wines.std())                  # Prints the standard deviation of the data.
# Out:
# fixed acidity            0.843868
# volatile acidity         0.101940
# citric acid              0.121020
# residual sugar           5.072058
# chlorides               47.178577
# free sulfur dioxide      0.000000
# total sulfur dioxide    42.498065
# density                  6.838541
# pH                       0.151001
# sulphates                0.114126
# alcohol                  1.261055
# quality                  0.885639
# dtype: float64

# %% [markdown]
# #### The above output shows how much the data deviated from the mean.

# %% [markdown]
# ## 7. Covariance and Correlation

# %% [markdown]
# 1. Covariance is a numerical measure that indicates the inter-dependency between two variables.
# 2. Covariance indicates how two variables behave together in relation to their averages.
# 3. A covariance of 0 indicates that the variables are totally independant, while a high and positive covariance value means that a variable is big when the other is big. Analogously, a negative covariance with a high absolute value means that one variable is big when the other is small.
# 4. Covariance can be calculated through the cov() function.

# %% [markdown]
# ### 7.1 Check the Covariance and Correlation scores . write your Observations?

# %% [markdown]
# #### Covariance

# %%
print(wines.cov())                # Prints the covariance of each attribute against every other attribute.
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              0.712114         -0.001899     0.029533
# volatile acidity          -0.001899          0.010392    -0.001909
# citric acid                0.029533         -0.001909     0.014646
# residual sugar             0.381022          0.045809     0.057829
# chlorides                  0.815119          0.036575     0.244885
# free sulfur dioxide        0.000000          0.000000     0.000000
# total sulfur dioxide       3.266013          0.392448     0.622989
# density                    0.420583         -0.011257     0.041395
# pH                        -0.054265         -0.002309    -0.002992
# sulphates                 -0.001651         -0.000609     0.000861
# alcohol                   -0.139165          0.001880    -0.011732
# quality                   -0.084947         -0.022113    -0.000987
#
#                       residual sugar    chlorides  free sulfur dioxide  \
# fixed acidity               0.381022     0.815119                  0.0
# volatile acidity            0.045809     0.036575                  0.0
# citric acid                 0.057829     0.244885                  0.0
# residual sugar             25.725770    10.790949                  0.0
# chlorides                  10.790949  2225.818110                  0.0
# free sulfur dioxide         0.000000     0.000000                  0.0
# total sulfur dioxide       86.531303    89.542800                  0.0
# density                     7.765899    -2.576634                  0.0
# pH                         -0.148684    -0.024557                  0.0
# sulphates                  -0.015435    -0.028057                  0.0
# alcohol                    -2.825366    -3.760579                  0.0
# quality                    -0.438316    -0.690818                  0.0
#
#                       total sulfur dioxide    density        pH  sulphates  \
# fixed acidity                     3.266013   0.420583 -0.054265  -0.001651
# volatile acidity                  0.392448  -0.011257 -0.002309  -0.000609
# citric acid                       0.622989   0.041395 -0.002992   0.000861
# residual sugar                   86.531303   7.765899 -0.148684  -0.015435
# chlorides                        89.542800  -2.576634 -0.024557  -0.028057
# free sulfur dioxide               0.000000   0.000000  0.000000   0.000000
# total sulfur dioxide           1806.085491  28.685530  0.014894   0.652645
# density                          28.685530  46.765637 -0.044973   0.041528
# pH                                0.014894  -0.044973  0.022801   0.002688
# sulphates                         0.652645   0.041528  0.002688   0.013025
# alcohol                         -23.401401  -0.761542  0.022681  -0.001947
# quality                          -6.576746  -0.155684  0.013297   0.005425
#
#                         alcohol   quality
# fixed acidity         -0.139165 -0.084947
# volatile acidity       0.001880 -0.022113
# citric acid           -0.011732 -0.000987
# residual sugar        -2.825366 -0.438316
# chlorides             -3.760579 -0.690818
# free sulfur dioxide    0.000000  0.000000
# total sulfur dioxide -23.401401 -6.576746
# density               -0.761542 -0.155684
# pH                     0.022681  0.013297
# sulphates             -0.001947  0.005425
# alcohol                1.590259  0.475468
# quality                0.475468  0.784356

# %% [markdown]
# ### Insights:
#
# - Hard to be understood and compared, because it gives us values in different scales as the variables change.
# - For a better comparison, we normalize covariance to a value that will always be between -1 and 1, so it can be better understood.

# %% [markdown]
# #### Correlation

# %%
print(wines.corr())             # Prints the correlation coefficient between each pair of attributes.
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.021161     0.289181
# volatile acidity          -0.021161          1.000000    -0.139789
# citric acid                0.289181         -0.139789     1.000000
# residual sugar             0.089021          0.088836     0.094212
# chlorides                  0.020474          0.017417     0.042890
# free sulfur dioxide             NaN               NaN          NaN
# total sulfur dioxide       0.091070          0.088713     0.121131
# density                    0.072881         -0.022164     0.050018
# pH                        -0.425858         -0.142107    -0.163748
# sulphates                 -0.017143         -0.051453     0.062331
# alcohol                   -0.130774          0.016678    -0.076872
# quality                   -0.113663         -0.235556    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.020474                  NaN
# volatile acidity            0.088836   0.017417                  NaN
# citric acid                 0.094212   0.042890                  NaN
# residual sugar              1.000000   0.045095                  NaN
# chlorides                   0.045095   1.000000                  NaN
# free sulfur dioxide              NaN        NaN                  NaN
# total sulfur dioxide        0.401439   0.044660                  NaN
# density                     0.223895  -0.007986                  NaN
# pH                         -0.194133  -0.003447                  NaN
# sulphates                  -0.026664  -0.005211                  NaN
# alcohol                    -0.441730  -0.063209                  NaN
# quality                    -0.097577  -0.016533                  NaN
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.072881 -0.425858  -0.017143
# volatile acidity                  0.088713 -0.022164 -0.142107  -0.051453
# citric acid                       0.121131  0.050018 -0.163748   0.062331
# residual sugar                    0.401439  0.223895 -0.194133  -0.026664
# chlorides                         0.044660 -0.007986 -0.003447  -0.005211
# free sulfur dioxide                    NaN       NaN       NaN        NaN
# total sulfur dioxide              1.000000  0.098703  0.002321   0.134562
# density                           0.098703  1.000000 -0.043552   0.053210
# pH                                0.002321 -0.043552  1.000000   0.155951
# sulphates                         0.134562  0.053210  0.155951   1.000000
# alcohol                          -0.436655 -0.088307  0.119110  -0.013531
# quality                          -0.174737 -0.025705  0.099427   0.053678
#
#                        alcohol   quality
# fixed acidity        -0.130774 -0.113663
# volatile acidity      0.016678 -0.235556
# citric acid          -0.076872 -0.009209
# residual sugar       -0.441730 -0.097577
# chlorides            -0.063209 -0.016533
# free sulfur dioxide        NaN       NaN
# total sulfur dioxide -0.436655 -0.174737
# density              -0.088307 -0.025705
# pH                    0.119110  0.099427
# sulphates            -0.013531  0.053678
# alcohol               1.000000  0.425727
# quality               0.425727  1.000000

# %% [markdown]
# ### Insights:
#
# 1. This value is the correlation. Correlation is always between -1, a perfect anti-correlation, and 1, perfect correlation
# 2. Finally, it is also important to note the famous concept that says that “correlation does not imply causation”.

# %% [markdown]
# ## 8. Pairplot for checking correlation:

# %%
import seaborn as sns

sns.pairplot(wines, kind='reg')
plt.show()

# %% [markdown]
# ### Insights:
#
# - It plots pairwise relationships in a dataset.
# - The diagonal Axes are histograms for each variable

# %% [markdown]
# ## 9. Heatmap of correlation:

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(wines.corr(), annot=True, fmt=".2", cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Insights:
#
# - Plot of rectangular data as a color-encoded matrix.

# %% [markdown]
# ## 10. Check the skewness:

# %%
wines.skew()
# Out:
# fixed acidity            0.647751
# volatile acidity         1.553432
# citric acid              1.281920
# residual sugar           1.077094
# chlorides               10.147967
# free sulfur dioxide      0.000000
# total sulfur dioxide     0.390710
# density                 14.149042
# pH                       0.457783
# sulphates                0.977194
# alcohol                  0.543830
# quality                  0.155796
# dtype: float64

# %% [markdown]
# - skew() return unbiased skew over requested axis.
# - The positive values indicate that the data is positively skewed. i.e. The mean and median is greater than the mode.

# %% [markdown]
# ## 11. Check the distribution of 'quality' column using distplot.

# %%
sns.distplot(wines['quality'])
# Out:
# /tmp/ipython-input-1427734418.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wines['quality'])
# <Axes: xlabel='quality', ylabel='Density'>

# %% [markdown]
# #### This is a plot of univariate distribution of the target variable.

# %% [markdown]
# # Conclusion:
#
# **Value of Exploratory Data Analysis:**
#
# - Exploratory Data Analysis is valuable to data science projects since it allows to get closer to the certainty that the future results will be valid, correctly interpreted, and applicable to the desired business contexts.
# - Such level of certainty can be achieved only after raw data is validated and checked for anomalies, ensuring that the data set was collected without errors.
# - EDA also helps to find insights that were not evident or worth investigating to business stakeholders and data scientists but can be very informative about a particular business.
#
# - EDA is performed in order to define and refine the selection of feature variables that will be used for machine learning.
# - Once data scientists become familiar with the data set, they often have to return to feature engineering step, since the initial features may turn out not to be serving their intended purpose.
# - Once the EDA stage is complete, data scientists get a firm feature set they need for supervised and unsupervised machine learning.
